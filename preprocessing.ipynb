# %% [markdown]
# # Preprocessing #
# Important notes:
#
# - We need to examine whether the current value is both positive and negative. In such cases, we'll take the absolute value, as the sign of the current indicates direction, which is not relevant here.
#
# - IPLA is derived from IP, as IPLA represents the measured value of IP.
#
# - Given the presence of very large values, it's crucial to standardize the data for consistency.
#     -  Exclude the 'time' column from the dataset :
#     columns_to_standardize = shot_data.drop(columns=['time'])
#
#     - Initialize the scaler :
#     scaler = StandardScaler()
#
#     - Fit and transform the data :
#     standardized_data = scaler.fit_transform(columns_to_standardize)
#
#     - Convert the result back into a DataFrame (optional):
#     standardized_df = pd.DataFrame(standardized_data, columns=columns_to_standardize.columns)
#
#     - include the 'time' column back:
#     standardized_df['time'] = shot_data['time']
#
# The standardization is done when time windows are created for the models.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
import numpy as np
import os
import glob
import pandas as pd
from sklearn.experimental import enable_iterative_imputer
import json
from sklearn.impute import IterativeImputer
from sklearn.ensemble import HistGradientBoostingRegressor

# %%
def replace_nan_with_mean(dataframe):
    """
    Replace NaN values in a DataFrame with the mean of their respective columns.

    Parameters:
    ----------
    dataframe : pandas.DataFrame
        A DataFrame where NaN values are to be replaced. It should contain numeric columns.

    Returns:
    -------
    pandas.DataFrame
        The DataFrame with NaN values replaced by the mean of their respective columns.
    """
    return dataframe.apply(lambda col: col.fillna(col.mean()))

# %%
def preprocessor(data_dict, features_combination_id=0, FFT=False):
    """
    Preprocessor modified to handle a dictionary of DataFrames.

    Parameters:
    ----------
    data_dict : dict
        A dictionary where keys are shot numbers and 
        values are filepaths to the file containing the feature data for that shot.
    features_combination_id : int
        Selects which feature set to use:
        - 0 for `features1`
        - 1 for `features2`
    FFT : bool
        If True, replaces 'Halpha13' with its FFT components.

    Saves:
    ------
    Preprocessed files into the folder `preprocessed_features0`.
    """

    # Define feature sets
    features1 = [
        'time','Wtot', 'DML', 'FIR_LIDs_core', 'FIR_LIDs_LFS', 'FIR_LIDs_HFS', 'IPLA',
        'Halpha13', 'Z_axis', 'POHM'
    ] + [f'Te_rho_z{i}' for i in range(1, 68)] + [f'Ne_rho_z{i}' for i in range(1, 68)]

    features2 = [
        'time','Wtot', 'DML', 'FIR_LIDs_core', 'FIR_LIDs_LFS', 'FIR_LIDs_HFS', 'IP',
        'Halpha13', 'Z_axis', 'POHM'
    ] + [f'Te_rho_z{i}' for i in range(1, 68)] + [f'Ne_rho_z{i}' for i in range(1, 68)]

    feature_sets = [features1, features2]
    selected_features = feature_sets[features_combination_id]

    # Create the output folder dynamically based on arguments
    feature_set_name = f"features{features_combination_id}"
    fft_suffix = "_FFT" if FFT else ""
    output_folder = f"preprocessed_{feature_set_name}{fft_suffix}"
    os.makedirs(output_folder, exist_ok=True)
    idx = 1
    for shot_number, filepath in data_dict.items():
        # Load the data
        data = pd.read_parquet(filepath)
        data.interpolate(method='linear', inplace=True) #added
        data.dropna(inplace=True) #added
         # Handle optional FFT on Halpha13
        effective_features = selected_features.copy()
        if FFT and 'Halpha13' in data.columns:
            alpha13_data = data['Halpha13'].values
            frequencies = np.fft.fftfreq(len(alpha13_data), d=np.mean(np.diff(data['time'].values)))
            data['Halpha13_FFT'] = frequencies
            data = data.drop(columns=['Halpha13'])  # Remove 'Halpha13' column
            effective_features.remove('Halpha13')  # Remove from the features
            effective_features.append('Halpha13_FFT')  # Add 'Halpha13_FFT' to features
        
        # Apply absolute value transformation for 'IP' and 'IPLA'
        for feature in ['IP', 'IPLA']:
            if feature in data.columns:
                data[feature] = data[feature].abs()
        
        data['time'].fillna(method='bfill', inplace=True)  # Fill NaNs at the start
        data['time'].fillna(method='ffill', inplace=True)  # Fill NaNs at the end
        
        # Filter and preprocess data for the current shot
        retained_data = data[effective_features].copy()
        retained_data.fillna(retained_data.mean(), inplace=True)
        # Exclude the 'time' column from standardization
        columns_to_standardize = retained_data.drop(columns=['time'])

        processed_data = retained_data

        # Save the processed data to a file in the output folder
        output_filepath = os.path.join(output_folder, f"{shot_number}_processed.parquet")
        processed_data.to_parquet(output_filepath)
        print(f"Processed and saved: {output_filepath} ({idx}/{len(data_dict)})")
        idx += 1

    return selected_features

# %%
pq_path = 'selected_experiments'
pq_all = glob.glob(os.path.join(pq_path, 'TCV_DATAno*build.parquet'))
pq_all = {int(os.path.basename(f).split("TCV_DATAno")[1].split("build.parquet")[0]): f for f in pq_all}

print(pq_all)
shotlist_all = list(pq_all.keys())

with open('HL_times_sel.json', 'r') as f:
    HL_times = json.load(f)
    HL_times = {int(k): v for k, v in HL_times.items()}

print(f"Total number of experiments: {len(shotlist_all)}")
print(f"Total number of shots with HL transition times: {len(HL_times)}")
# Out:
# {63888: 'selected_experiments/TCV_DATAno63888build.parquet', 63877: 'selected_experiments/TCV_DATAno63877build.parquet', 60995: 'selected_experiments/TCV_DATAno60995build.parquet', 77409: 'selected_experiments/TCV_DATAno77409build.parquet', 60992: 'selected_experiments/TCV_DATAno60992build.parquet', 73330: 'selected_experiments/TCV_DATAno73330build.parquet', 61279: 'selected_experiments/TCV_DATAno61279build.parquet', 45103: 'selected_experiments/TCV_DATAno45103build.parquet', 64855: 'selected_experiments/TCV_DATAno64855build.parquet', 61281: 'selected_experiments/TCV_DATAno61281build.parquet', 61702: 'selected_experiments/TCV_DATAno61702build.parquet', 56662: 'selected_experiments/TCV_DATAno56662build.parquet', 61021: 'selected_experiments/TCV_DATAno61021build.parquet', 65488: 'selected_experiments/TCV_DATAno65488build.parquet', 64368: 'selected_experiments/TCV_DATAno64368build.parquet', 77604: 'selected_experiments/TCV_DATAno77604build.parquet', 61042: 'selected_experiments/TCV_DATAno61042build.parquet', 63923: 'selected_experiments/TCV_DATAno63923build.parquet', 53627: 'selected_experiments/TCV_DATAno53627build.parquet', 61010: 'selected_experiments/TCV_DATAno61010build.parquet', 65564: 'selected_experiments/TCV_DATAno65564build.parquet', 63853: 'selected_experiments/TCV_DATAno63853build.parquet', 59064: 'selected_experiments/TCV_DATAno59064build.parquet', 64662: 'selected_experiments/TCV_DATAno64662build.parquet', 67186: 'selected_experiments/TCV_DATAno67186build.parquet', 58182: 'selected_experiments/TCV_DATAno58182build.parquet', 65322: 'selected_experiments/TCV_DATAno65322build.parquet', 61005: 'selected_experiments/TCV_DATAno61005build.parquet', 64670: 'selected_experiments/TCV_DATAno64670build.parquet', 59076: 'selected_experiments/TCV_DATAno59076build.parquet', 66494: 'selected_experiments/TCV_DATAno66494build.parquet', 61057: 'selected_experiments/TCV_DATAno61057build.parquet', 69133: 'selected_experiments/TCV_DATAno69133build.parquet', 64913: 'selected_experiments/TCV_DATAno64913build.parquet', 64914: 'selected_experiments/TCV_DATAno64914build.parquet', 77595: 'selected_experiments/TCV_DATAno77595build.parquet', 64770: 'selected_experiments/TCV_DATAno64770build.parquet', 61703: 'selected_experiments/TCV_DATAno61703build.parquet', 65288: 'selected_experiments/TCV_DATAno65288build.parquet', 73929: 'selected_experiments/TCV_DATAno73929build.parquet', 77602: 'selected_experiments/TCV_DATAno77602build.parquet', 64369: 'selected_experiments/TCV_DATAno64369build.parquet', 61716: 'selected_experiments/TCV_DATAno61716build.parquet', 52302: 'selected_experiments/TCV_DATAno52302build.parquet', 61060: 'selected_experiments/TCV_DATAno61060build.parquet', 61711: 'selected_experiments/TCV_DATAno61711build.parquet', 64647: 'selected_experiments/TCV_DATAno64647build.parquet', 68987: 'selected_experiments/TCV_DATAno68987build.parquet', 64924: 'selected_experiments/TCV_DATAno64924build.parquet', 45105: 'selected_experiments/TCV_DATAno45105build.parquet', 64923: 'selected_experiments/TCV_DATAno64923build.parquet', 65253: 'selected_experiments/TCV_DATAno65253build.parquet', 60275: 'selected_experiments/TCV_DATAno60275build.parquet', 63847: 'selected_experiments/TCV_DATAno63847build.parquet', 64915: 'selected_experiments/TCV_DATAno64915build.parquet', 64912: 'selected_experiments/TCV_DATAno64912build.parquet', 65336: 'selected_experiments/TCV_DATAno65336build.parquet', 59065: 'selected_experiments/TCV_DATAno59065build.parquet', 61044: 'selected_experiments/TCV_DATAno61044build.parquet', 26386: 'selected_experiments/TCV_DATAno26386build.parquet', 61043: 'selected_experiments/TCV_DATAno61043build.parquet', 69127: 'selected_experiments/TCV_DATAno69127build.parquet', 59825: 'selected_experiments/TCV_DATAno59825build.parquet', 47962: 'selected_experiments/TCV_DATAno47962build.parquet', 72929: 'selected_experiments/TCV_DATAno72929build.parquet', 77426: 'selected_experiments/TCV_DATAno77426build.parquet', 79827: 'selected_experiments/TCV_DATAno ...
# Total number of experiments: 244
# Total number of shots with HL transition times: 245

# %%
import warnings
warnings.filterwarnings("ignore")

features = preprocessor (pq_all, features_combination_id=1, FFT=True)

print(f"the preprocessed_data has been saved")
# Out:
# Processed and saved: preprocessed_features1_FFT/63888_processed.parquet (1/244)
# Processed and saved: preprocessed_features1_FFT/63877_processed.parquet (2/244)
# Processed and saved: preprocessed_features1_FFT/60995_processed.parquet (3/244)
# Processed and saved: preprocessed_features1_FFT/77409_processed.parquet (4/244)
# Processed and saved: preprocessed_features1_FFT/60992_processed.parquet (5/244)
# Processed and saved: preprocessed_features1_FFT/73330_processed.parquet (6/244)
# Processed and saved: preprocessed_features1_FFT/61279_processed.parquet (7/244)
# Processed and saved: preprocessed_features1_FFT/45103_processed.parquet (8/244)
# Processed and saved: preprocessed_features1_FFT/64855_processed.parquet (9/244)
# Processed and saved: preprocessed_features1_FFT/61281_processed.parquet (10/244)
# Processed and saved: preprocessed_features1_FFT/61702_processed.parquet (11/244)
# Processed and saved: preprocessed_features1_FFT/56662_processed.parquet (12/244)
# Processed and saved: preprocessed_features1_FFT/61021_processed.parquet (13/244)
# Processed and saved: preprocessed_features1_FFT/65488_processed.parquet (14/244)
# Processed and saved: preprocessed_features1_FFT/64368_processed.parquet (15/244)
# Processed and saved: preprocessed_features1_FFT/77604_processed.parquet (16/244)
# Processed and saved: preprocessed_features1_FFT/61042_processed.parquet (17/244)
# Processed and saved: preprocessed_features1_FFT/63923_processed.parquet (18/244)
# Processed and saved: preprocessed_features1_FFT/53627_processed.parquet (19/244)
# Processed and saved: preprocessed_features1_FFT/61010_processed.parquet (20/244)
# Processed and saved: preprocessed_features1_FFT/65564_processed.parquet (21/244)
# Processed and saved: preprocessed_features1_FFT/63853_processed.parquet (22/244)
# Processed and saved: preprocessed_features1_FFT/59064_processed.parquet (23/244)
# Processed and saved: preprocessed_features1_FFT/64662_processed.parquet (24/244)
# Processed and saved: preprocessed_features1_FFT/67186_processed.parquet (25/244)
# Processed and saved: preprocessed_features1_FFT/58182_processed.parquet (26/244)
# Processed and saved: preprocessed_features1_FFT/65322_processed.parquet (27/244)
# Processed and saved: preprocessed_features1_FFT/61005_processed.parquet (28/244)
# Processed and saved: preprocessed_features1_FFT/64670_processed.parquet (29/244)
# Processed and saved: preprocessed_features1_FFT/59076_processed.parquet (30/244)
# Processed and saved: preprocessed_features1_FFT/66494_processed.parquet (31/244)
# Processed and saved: preprocessed_features1_FFT/61057_processed.parquet (32/244)
# Processed and saved: preprocessed_features1_FFT/69133_processed.parquet (33/244)
# Processed and saved: preprocessed_features1_FFT/64913_processed.parquet (34/244)
# Processed and saved: preprocessed_features1_FFT/64914_processed.parquet (35/244)
# Processed and saved: preprocessed_features1_FFT/77595_processed.parquet (36/244)
# Processed and saved: preprocessed_features1_FFT/64770_processed.parquet (37/244)
# Processed and saved: preprocessed_features1_FFT/61703_processed.parquet (38/244)
# Processed and saved: preprocessed_features1_FFT/65288_processed.parquet (39/244)
# Processed and saved: preprocessed_features1_FFT/73929_processed.parquet (40/244)
# Processed and saved: preprocessed_features1_FFT/77602_processed.parquet (41/244)
# Processed and saved: preprocessed_features1_FFT/64369_processed.parquet (42/244)
# Processed and saved: preprocessed_features1_FFT/61716_processed.parquet (43/244)
# Processed and saved: preprocessed_features1_FFT/52302_processed.parquet (44/244)
# Processed and saved: preprocessed_features1_FFT/61060_processed.parquet (45/244)
# Processed and saved: preprocessed_features1_FFT/61711_processed.parquet (46/244)
# Processed and saved: preprocessed_features1_FFT/64647_processed.parquet (47/244)
# Processed and saved: preprocessed_features1_FFT/68987_processed.parquet (48/244)
# Processed and saved: preprocessed_features1_FFT/64924_processed.parquet (49/244)
# Processed and saved: preprocessed_features1_FFT/45105_processed.parquet (50/244)
# Processed and saved: preprocessed_features1_FFT/64923_processed.parquet (51/244)
# Processed and saved: preprocessed_features1_FFT/65253_processed.parquet (52/244)
# Processed and saved: preprocessed_features1_FFT/60275_processed.parquet (53/244)
# Processed and saved: preprocessed_features1_FFT/63847_processed.parquet (54/244)
# Processed and saved: preprocessed_features1_FFT/64915_processed.parquet (55/244)
# Processed and saved: preprocessed_features1_FFT/64912_processed.parquet (56/244)
# Processed and saved: preprocessed_features1_FFT/65336_processed.parquet (57/244)
# Processed and saved: preprocessed_features1_FFT/59065_processed.parquet (58/244)
# Processed and saved: preprocessed_features1_FFT/61044_processed.parquet (59/244)
# Processed and saved: preprocessed_features1_FFT/26386_processed.parquet (60/244)
# Processed and saved: preprocessed_features1_FFT/61043_processed.parquet (61/244)
# Processed and saved: preprocessed_features1_FFT/69127_processed.parquet (62/244)
# Processed and saved: preprocessed_features1_FFT/59825_processed.parquet (63/244)
# Processed and saved: preprocessed_features1_FFT/47962_processed.parquet (64/244)
# Processed and saved: preprocessed_features1_FFT/72929_processed.parquet (65/244)
# Processed and saved: preprocessed_features1_FFT/77426_processed.parquet (66/244)
# Processed and saved: preprocessed_features1_FFT/79827_processed.parquet (67/244)
# Processed and saved: preprocessed_features1_FFT/77092_processed.parquet (68/244)
# Processed and saved: preprocessed_features1_FFT/61009_processed.parquet (69/244)
# Processed and saved: preprocessed_features1_FFT/73631_processed.parquet (70/244)
# Processed and saved: preprocessed_features1_FFT/64918_processed.parquet (71/244)
# Processed and saved: preprocessed_features1_FFT/64340_processed.parquet (72/244)
# Processed and saved: preprocessed_features1_FFT/75263_processed.parquet (73/244)
# Processed and saved: preprocessed_features1_FFT/57623_processed.parquet (74/244)
# Processed and saved: preprocessed_features1_FFT/57706_processed.parquet (75/244)
# Processed and saved: preprocessed_features1_FFT/57077_processed.parquet (76/244)
# Processed and saved: preprocessed_features1_FFT/57624_processed.parquet (77/244)
# Processed and saved: preprocessed_features1_FFT/75264_processed.parquet (78/244)
# Processed and saved: preprocessed_features1_FFT/65318_processed.parquet (79/244)
# Processed and saved: preprocessed_features1_FFT/65469_processed.parquet (80/244)
# Processed and saved: preprocessed_features1_FFT/72828_processed.parquet (81/244)
# Processed and saved: preprocessed_features1_FFT/68643_processed.parquet (82/244)
# Processed and saved: preprocessed_features1_FFT/61038_processed.parquet (83/244)
# Processed and saved: preprocessed_features1_FFT/73936_processed.parquet (84/244)
# Processed and saved: preprocessed_features1_FFT/64371_processed.parquet (85/244)
# Processed and saved: preprocessed_features1_FFT/57013_processed.parquet (86/244)
# Processed and saved: preprocessed_features1_FFT/77193_processed.parquet (87/244)
# Processed and saved: preprocessed_features1_FFT/61275_processed.parquet (88/244)
# Processed and saved: preprocessed_features1_FFT/64859_processed.parquet (89/244)
# Processed and saved: preprocessed_features1_FFT/73931_processed.parquet (90/244)
# Processed and saved: preprocessed_features1_FFT/64389_processed.parquet (91/244)
# Processed and saved: preprocessed_features1_FFT/64376_processed.parquet (92/244)
# Processed and saved: preprocessed_features1_FFT/65282_processed.parquet (93/244)
# Processed and saved: preprocessed_features1_FFT/77598_processed.parquet (94/244)
# Processed and saved: preprocessed_features1_FFT/71208_processed.parquet (95/244)
# Processed and saved: preprocessed_features1_FFT/65285_processed.parquet (96/244)
# Processed and saved: preprocessed_features1_FFT/64658_processed.parquet (97/244)
# Processed and saved: preprocessed_features1_FFT/64363_processed.parquet (98/244)
# Processed and saved: preprocessed_features1_FFT/64336_processed.parquet (99/244)
# Processed and saved: preprocessed_features1_FFT/61260_processed.parquet (100/244)
# Processed and saved: preprocessed_features1_FFT/64364_processed.parquet (101/244)
# Processed and saved: preprocessed_features1_FFT/75265_processed.parquet (102/244)
# Processed and saved: preprocessed_features1_FFT/57622_processed.parquet (103/244)
# Processed and saved: preprocessed_features1_FFT/64919_processed.parquet (104/244)
# Processed and saved: preprocessed_features1_FFT/61242_processed.parquet (105/244)
# Processed and saved: preprocessed_features1_FFT/57024_processed.parquet (106/244)
# Processed and saved: preprocessed_features1_FFT/68699_processed.parquet (107/244)
# Processed and saved: preprocessed_features1_FFT/57715_processed.parquet (108/244)
# Processed and saved: preprocessed_features1_FFT/79826_processed.parquet (109/244)
# Processed and saved: preprocessed_features1_FFT/65482_processed.parquet (110/244)
# Processed and saved: preprocessed_features1_FFT/64659_processed.parquet (111/244)
# Processed and saved: preprocessed_features1_FFT/57218_processed.parquet (112/244)
# Processed and saved: preprocessed_features1_FFT/77599_processed.parquet (113/244)
# Processed and saved: preprocessed_features1_FFT/65283_processed.parquet (114/244)
# Processed and saved: preprocessed_features1_FFT/77411_processed.parquet (115/244)
# Processed and saved: preprocessed_features1_FFT/57000_processed.parquet (116/244)
# Processed and saved: preprocessed_features1_FFT/64365_processed.parquet (117/244)
# Processed and saved: preprocessed_features1_FFT/46853_processed.parquet (118/244)
# Processed and saved: preprocessed_features1_FFT/61039_processed.parquet (119/244)
# Processed and saved: preprocessed_features1_FFT/76702_processed.parquet (120/244)
# Processed and saved: preprocessed_features1_FFT/65319_processed.parquet (121/244)
# Processed and saved: preprocessed_features1_FFT/65468_processed.parquet (122/244)
# Processed and saved: preprocessed_features1_FFT/63882_processed.parquet (123/244)
# Processed and saved: preprocessed_features1_FFT/64858_processed.parquet (124/244)
# Processed and saved: preprocessed_features1_FFT/61274_processed.parquet (125/244)
# Processed and saved: preprocessed_features1_FFT/73368_processed.parquet (126/244)
# Processed and saved: preprocessed_features1_FFT/64370_processed.parquet (127/244)
# Processed and saved: preprocessed_features1_FFT/57026_processed.parquet (128/244)
# Processed and saved: preprocessed_features1_FFT/68268_processed.parquet (129/244)
# Processed and saved: preprocessed_features1_FFT/57103_processed.parquet (130/244)
# Processed and saved: preprocessed_features1_FFT/64680_processed.parquet (131/244)
# Processed and saved: preprocessed_features1_FFT/61058_processed.parquet (132/244)
# Processed and saved: preprocessed_features1_FFT/63849_processed.parquet (133/244)
# Processed and saved: preprocessed_features1_FFT/64678_processed.parquet (134/244)
# Processed and saved: preprocessed_features1_FFT/62744_processed.parquet (135/244)
# Processed and saved: preprocessed_features1_FFT/73632_processed.parquet (136/244)
# Processed and saved: preprocessed_features1_FFT/42514_processed.parquet (137/244)
# Processed and saved: preprocessed_features1_FFT/69129_processed.parquet (138/244)
# Processed and saved: preprocessed_features1_FFT/64335_processed.parquet (139/244)
# Processed and saved: preprocessed_features1_FFT/73927_processed.parquet (140/244)
# Processed and saved: preprocessed_features1_FFT/64367_processed.parquet (141/244)
# Processed and saved: preprocessed_features1_FFT/79815_processed.parquet (142/244)
# Processed and saved: preprocessed_features1_FFT/65281_processed.parquet (143/244)
# Processed and saved: preprocessed_features1_FFT/65487_processed.parquet (144/244)
# Processed and saved: preprocessed_features1_FFT/67112_processed.parquet (145/244)
# Processed and saved: preprocessed_features1_FFT/77330_processed.parquet (146/244)
# Processed and saved: preprocessed_features1_FFT/64372_processed.parquet (147/244)
# Processed and saved: preprocessed_features1_FFT/64327_processed.parquet (148/244)
# Processed and saved: preprocessed_features1_FFT/73935_processed.parquet (149/244)
# Processed and saved: preprocessed_features1_FFT/57010_processed.parquet (150/244)
# Processed and saved: preprocessed_features1_FFT/69514_processed.parquet (151/244)
# Processed and saved: preprocessed_features1_FFT/63880_processed.parquet (152/244)
# Processed and saved: preprocessed_features1_FFT/60812_processed.parquet (153/244)
# Processed and saved: preprocessed_features1_FFT/63887_processed.parquet (154/244)
# Processed and saved: preprocessed_features1_FFT/61254_processed.parquet (155/244)
# Processed and saved: preprocessed_features1_FFT/79825_processed.parquet (156/244)
# Processed and saved: preprocessed_features1_FFT/60830_processed.parquet (157/244)
# Processed and saved: preprocessed_features1_FFT/53629_processed.parquet (158/244)
# Processed and saved: preprocessed_features1_FFT/57751_processed.parquet (159/244)
# Processed and saved: preprocessed_features1_FFT/61246_processed.parquet (160/244)
# Processed and saved: preprocessed_features1_FFT/64342_processed.parquet (161/244)
# Processed and saved: preprocessed_features1_FFT/63848_processed.parquet (162/244)
# Processed and saved: preprocessed_features1_FFT/64686_processed.parquet (163/244)
# Processed and saved: preprocessed_features1_FFT/64374_processed.parquet (164/244)
# Processed and saved: preprocessed_features1_FFT/57011_processed.parquet (165/244)
# Processed and saved: preprocessed_features1_FFT/61277_processed.parquet (166/244)
# Processed and saved: preprocessed_features1_FFT/73934_processed.parquet (167/244)
# Processed and saved: preprocessed_features1_FFT/64373_processed.parquet (168/244)
# Processed and saved: preprocessed_features1_FFT/77196_processed.parquet (169/244)
# Processed and saved: preprocessed_features1_FFT/57732_processed.parquet (170/244)
# Processed and saved: preprocessed_features1_FFT/69512_processed.parquet (171/244)
# Processed and saved: preprocessed_features1_FFT/64648_processed.parquet (172/244)
# Processed and saved: preprocessed_features1_FFT/60813_processed.parquet (173/244)
# Processed and saved: preprocessed_features1_FFT/63879_processed.parquet (174/244)
# Processed and saved: preprocessed_features1_FFT/61719_processed.parquet (175/244)
# Processed and saved: preprocessed_features1_FFT/69515_processed.parquet (176/244)
# Processed and saved: preprocessed_features1_FFT/60814_processed.parquet (177/244)
# Processed and saved: preprocessed_features1_FFT/74916_processed.parquet (178/244)
# Processed and saved: preprocessed_features1_FFT/64366_processed.parquet (179/244)
# Processed and saved: preprocessed_features1_FFT/61237_processed.parquet (180/244)
# Processed and saved: preprocessed_features1_FFT/65481_processed.parquet (181/244)
# Processed and saved: preprocessed_features1_FFT/42197_processed.parquet (182/244)
# Processed and saved: preprocessed_features1_FFT/61028_processed.parquet (183/244)
# Processed and saved: preprocessed_features1_FFT/65280_processed.parquet (184/244)
# Processed and saved: preprocessed_features1_FFT/64393_processed.parquet (185/244)
# Processed and saved: preprocessed_features1_FFT/57009_processed.parquet (186/244)
# Processed and saved: preprocessed_features1_FFT/63944_processed.parquet (187/244)
# Processed and saved: preprocessed_features1_FFT/63943_processed.parquet (188/244)
# Processed and saved: preprocessed_features1_FFT/65474_processed.parquet (189/244)
# Processed and saved: preprocessed_features1_FFT/64386_processed.parquet (190/244)
# Processed and saved: preprocessed_features1_FFT/61631_processed.parquet (191/244)
# Processed and saved: preprocessed_features1_FFT/61713_processed.parquet (192/244)
# Processed and saved: preprocessed_features1_FFT/65317_processed.parquet (193/244)
# Processed and saved: preprocessed_features1_FFT/74498_processed.parquet (194/244)
# Processed and saved: preprocessed_features1_FFT/61714_processed.parquet (195/244)
# Processed and saved: preprocessed_features1_FFT/68919_processed.parquet (196/244)
# Processed and saved: preprocessed_features1_FFT/60097_processed.parquet (197/244)
# Processed and saved: preprocessed_features1_FFT/64917_processed.parquet (198/244)
# Processed and saved: preprocessed_features1_FFT/30290_processed.parquet (199/244)
# Processed and saved: preprocessed_features1_FFT/65321_processed.parquet (200/244)
# Processed and saved: preprocessed_features1_FFT/68628_processed.parquet (201/244)
# Processed and saved: preprocessed_features1_FFT/65527_processed.parquet (202/244)
# Processed and saved: preprocessed_features1_FFT/64820_processed.parquet (203/244)
# Processed and saved: preprocessed_features1_FFT/57095_processed.parquet (204/244)
# Processed and saved: preprocessed_features1_FFT/63920_processed.parquet (205/244)
# Processed and saved: preprocessed_features1_FFT/64060_processed.parquet (206/244)
# Processed and saved: preprocessed_features1_FFT/67182_processed.parquet (207/244)
# Processed and saved: preprocessed_features1_FFT/64666_processed.parquet (208/244)
# Processed and saved: preprocessed_features1_FFT/64067_processed.parquet (209/244)
# Processed and saved: preprocessed_features1_FFT/53623_processed.parquet (210/244)
# Processed and saved: preprocessed_features1_FFT/64378_processed.parquet (211/244)
# Processed and saved: preprocessed_features1_FFT/64857_processed.parquet (212/244)
# Processed and saved: preprocessed_features1_FFT/73367_processed.parquet (213/244)
# Processed and saved: preprocessed_features1_FFT/48580_processed.parquet (214/244)
# Processed and saved: preprocessed_features1_FFT/53601_processed.parquet (215/244)
# Processed and saved: preprocessed_features1_FFT/58460_processed.parquet (216/244)
# Processed and saved: preprocessed_features1_FFT/61712_processed.parquet (217/244)
# Processed and saved: preprocessed_features1_FFT/61630_processed.parquet (218/244)
# Processed and saved: preprocessed_features1_FFT/69115_processed.parquet (219/244)
# Processed and saved: preprocessed_features1_FFT/64392_processed.parquet (220/244)
# Processed and saved: preprocessed_features1_FFT/64338_processed.parquet (221/244)
# Processed and saved: preprocessed_features1_FFT/65557_processed.parquet (222/244)
# Processed and saved: preprocessed_features1_FFT/63945_processed.parquet (223/244)
# Processed and saved: preprocessed_features1_FFT/64774_processed.parquet (224/244)
# Processed and saved: preprocessed_features1_FFT/33567_processed.parquet (225/244)
# Processed and saved: preprocessed_features1_FFT/57093_processed.parquet (226/244)
# Processed and saved: preprocessed_features1_FFT/57094_processed.parquet (227/244)
# Processed and saved: preprocessed_features1_FFT/59066_processed.parquet (228/244)
# Processed and saved: preprocessed_features1_FFT/65566_processed.parquet (229/244)
# Processed and saved: preprocessed_features1_FFT/59061_processed.parquet (230/244)
# Processed and saved: preprocessed_features1_FFT/53625_processed.parquet (231/244)
# Processed and saved: preprocessed_features1_FFT/82610_processed.parquet (232/244)
# Processed and saved: preprocessed_features1_FFT/65561_processed.parquet (233/244)
# Processed and saved: preprocessed_features1_FFT/77089_processed.parquet (234/244)
# Processed and saved: preprocessed_features1_FFT/57081_processed.parquet (235/244)
# Processed and saved: preprocessed_features1_FFT/64916_processed.parquet (236/244)
# Processed and saved: preprocessed_features1_FFT/76322_processed.parquet (237/244)
# Processed and saved: preprocessed_features1_FFT/64911_processed.parquet (238/244)
# Processed and saved: preprocessed_features1_FFT/61000_processed.parquet (239/244)
# Processed and saved: preprocessed_features1_FFT/61055_processed.parquet (240/244)
# Processed and saved: preprocessed_features1_FFT/63843_processed.parquet (241/244)
# Processed and saved: preprocessed_features1_FFT/65320_processed.parquet (242/244)
# Processed and saved: preprocessed_features1_FFT/59073_processed.parquet (243/244)
# Processed and saved: preprocessed_features1_FFT/64675_processed.parquet (244/244)
# the preprocessed_data has been saved
